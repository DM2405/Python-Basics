# %% [markdown]
# The list is a sequence data type which is used to store the collection of data. List items are ordered,mutable(changeable),can contain element of different data types, allow duplicate values, enclosed in [ ] square brackets and separated by commas.

# %% [markdown]
# ● List creation
# ● Creating a list with multiple distinct or duplicate elements
# ● Accessing elements from a multidimensional list
# ● Getting the size of Python list

# %%
#1. Creation of Lists
my_list = []
print(my_list)

names = ["", "science", "Python"]
print(names)

data = ["data", "science", "Python", 1, 9.07, True, "😁", 'data']
print(data)
# Out:
# []
# ['', 'science', 'Python']
# ['data', 'science', 'Python', 1, 9.07, True, '😁', 'data']

# %%
#2. Accessing List Elements
#Indexing : Accessing Individual Elements using their index(starts from 0)
fruits = ["orange", "mango", "pineapple"]

# %%
print(fruits[2])
print(fruits[-2])
# Out:
# pineapple
# mango

# %%
#3.Slicing : Access the element using slicing
age = [20, 78, 90, 100, 25, 76]
age

print(age[1:5])
print(age[-5: -2])
# Out:
# [78, 90, 100, 25]
# [78, 90, 100]

# %%
#4. List Methods

# %%
#A ) Adding Elements to a Python List

# %% [markdown]
# Method 1: Using append() Method
# Elements can be added to the List by using the built-in append() function. Only one element at a time can be added to the list by using the append() method, for the addition of multiple elements with the append() method, loops are used. Lists can also be added to the existing list with the use of the append() method.
#
# Syntax: list_name.append(element)

# %%
name = ["raj", "king", "data"]
name.append("sonam")
name
# Out:
# ['raj', 'king', 'data', 'sonam']

# %% [markdown]
# Method 2: Using insert() method
# append() method only works for the addition of elements at the end of the List, for the addition of elements at the desired position, insert() method is used. Unlike append() which takes only one argument, the insert() method requires two arguments(position, value).
#
# Syntax: list_name.insert(position, element)

# %%
fruits = ['apple', 'mango','pineapple']
print(fruits)
fruits.insert(2, 'guava')
fruits.insert(3,'🍌' )
fruits.insert(1, ['lemon', 'lichi'])
# Out:
# ['apple', 'mango', 'pineapple']

# %%
print(fruits)
len(fruits)
# Out:
# ['apple', ['lemon', 'lichi'], 'mango', 'guava', '🍌', 'pineapple']
# 6

# %% [markdown]
# Method 3: Using extend() method
# Other than append() and insert() methods, there’s one more method for the Addition of elements, extend(), this method is used to add multiple elements at the same time at the end of the list.
#
# Syntax: list_name.extend([element1, element2, …elementn])

# %%
fruits = ['apple', 'mango', 'pineapple']
fruits.extend(['guava', 'orange','🍉','🍉'])
fruits
# Out:
# ['apple', 'mango', 'pineapple', 'guava', 'orange', '🍉', '🍉']

# %%
#B) Removing Elements from the List

# %% [markdown]
# Method 1: Using remove() method
# Elements can be removed from the List by using the built-in remove() function but an Error arises if the element doesn’t exist in the list. Remove() method only removes one element at a time, to remove a range of elements, the iterator is used. The remove() method removes the specified item.
#
# Note: Remove method in List will only remove the first occurrence of the searched element.
#
# Syntax: list_name.remove(element)

# %%
fruits = ['apple', 'mango', 'pineapple','apple', 'guava', 'orange', 'mango', '🍉','apple']

# %%
fruits.remove('🍉')
fruits.remove('apple')

# %%
fruits
# Out:
# ['mango', 'pineapple', 'apple', 'guava', 'orange', 'mango', 'apple']

# %% [markdown]
# Method 2: Using pop() method
# pop() function can also be used to remove and return an element from the list, but by default it removes only the last element of the list, to remove an element from a specific position of the List, the index of the element is passed as an argument to thepop() method.
#
# Syntax:
# list_name.pop()--> last element
# list_name.pop(position)--> positional element

# %%
fruits
# Out:
# ['mango', 'pineapple', 'guava', 'orange', 'mango']

# %%
fruits.pop()
# Out:
# 'mango'

# %% [markdown]
# Reversing a List
# A list can be reversed by using the reverse() method in Python.
#
# Syntax: list_name.reverse()

# %%
fruits
# Out:
# ['mango', 'pineapple', 'guava', 'orange']

# %%
fruits.reverse()

# %%
fruits
# Out:
# ['orange', 'guava', 'pineapple', 'mango']
